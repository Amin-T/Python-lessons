# %% [markdown]
# [![Logo 2 (640x640) (200x144).jpg](data:image/jpeg;base64,...)](https://www.fiverr.com/share/q5V2x5)

# %% [markdown]
# # **Python Basics course exercises and solutions**
#
# This notebook will test what you have learned in the Python Basics course. To check you solutions, double-click on the __SOLUTION__.
#
# For more learning notebooks click [here](https://github.com/Amin-T).
#
# To learn useful Python tips and tricks, watch these [videos](https://www.youtube.com/channel/UC4WD4PpbbP9i_GJdFBCpSYQ/).

# %% [markdown]
# ## **Ex. 1:**
#
# Create a list containing the stock symbols below, and call it `stock`:
#
#     SP500, AAPL, TSLA, AMZN, MSFT

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# stock = ['SP500', 'AAPL', 'TSLA', 'AMZN', 'MSFT']
#
# -->

# %% [markdown]
# Using list indexing and string indexing, write a code that returns the `500` from `SP500`.

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# stock[0][2:]
#
# -->

# %% [markdown]
# ## **Ex. 2:**
# Create a list containing the stock prices below, and call it `price`:
#
#     3390.68, 116.6, 424, 3286.33, 213.20

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# price = [3390.65, 116.6, 424, 3286.33, 213.20]
#
# -->

# %% [markdown]
# Now, calculate the average of all prices and assigne the value to variable `mean_price`.

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# mean_price = (price[0] + price[1] + price[2] + price[3] + price[4]) / 5
#
# # OR better solution
#
# mean_price = sum(price)/len(price)
#
# -->

# %% [markdown]
# ## **Ex. 3:**
#
# Using the information from previous excecises, create a dictionary called `stock_prices` where the keys are stock symbols and values are prices.

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# stock_prices = {
#     'SP500': 3390.68,
#     'AAPL': 116.6,
#     'TSLA': 424,
#     'AMZN': 3286.33,
#     'MSFT': 213.20
# }
#
# -->

# %% [markdown]
# Now, use a `for` loop to print the statements below for all stocks in the dictionary.
#
#     The current price for stock <symbol> is : <price>.

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# for s in stock_prices.keys():
#   print('The current price for stock {s} is : {p}.'.format(s=s, p=stock_prices[s]))
#
# -->

# %% [markdown]
# Next, add the `mean_price` calculated in __Ex. 2__ to the dictionary as a new key-value.

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# stock_prices['mean_price'] = mean_price
#
# -->

# %% [markdown]
# # **Ex. 4:**
# Define a function that returns the average value for any list of numbers with length N.
# Test your function on `price` list. Does it give the same results as `mean_price` in __Ex. 2__?

# %%
# Write your answer

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# def avg_func(list):
#   avg = sum(list)/len(list)
#   return avg
#
# # to check if the function works, the below code sould retrun true:
#
# avg_func(price) == mean_price
#
# -->

# %% [markdown]
# # **Ex. 5:**
# Consider the text below, which is the definition of Machine Learning from [Wikipedia](https://en.wikipedia.org/wiki/Machine_learning)
#
#     Machine Learning is an application of artificial intelligence (AI) that
#     provides systems the ability to automatically learn and improve from
#     experience without being explicitly programmed. Machine Learning focuses on
#     the development of computer programs that can access data and use it to
#     learn for themselves.
# The purpose of this excercise is to create a function that get a text and a single word, and counts the gven word in the text. Replace `YOUR_CODE` with proper codes to complete the script, and run the codes to get the correct results.

# %%
def word_count(text, word):
  text_lower = YOUR_CODE # lower case all words in the text
  word_lower = YOUR_CODE # lower case given word
  counter = 0
  for w in text_lower.split():
    if YOUR_CODE: # check if the given word is in w
      counter = counter + 1
    
  if YOUR_CODE: # statement to return if the given word is not present in the text
    print('There is no \"{}\" in the text.'.format(word))
  elif YOUR_CODE: # statement to return if the given word occures in the text only once
    print('There is only one \"{}\" in the text.'.format(word))
  else: # statement to return if the given word occures in the text more than once
    print(YOUR_CODE)

# %%
# Test the function

text = 'Machine Learning is an application of artificial intelligence (AI) that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine Learning focuses on the development of computer programs that can access data and use it to learn for themselves.'

word_count(text, word='BigData')

word_count(text, word='AI')

word_count(text, word='Machine')
# Out:
# There is no "BigData" in the text.
# There is only one "AI" in the text.
# There are 2 "Machine"s in the text.

# %% [markdown]
# **SOLUTION** (double-click)
# <!--
#
# def word_count(text, word):
#   text_lower = text.lower()
#   word_lower = word.lower()
#   counter = 0
#   for w in text_lower.split():
#     if word_lower in w:
#       counter = counter + 1
#
#   if counter == 0:
#     print('There is no \"{}\" in the text.'.format(word))
#   elif counter == 1:
#     print('There is only one \"{}\" in the text.'.format(word))
#   else:
#     print('There are {} \"{}\"s in the text.'.format(counter, word))
#
# -->

# %% [markdown]
# # **Good Luck!!!**
