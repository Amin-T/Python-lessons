# %% [markdown]
# [![banner (640x99).jpg](data:image/jpeg;base64,...)](https://www.fiverr.com/share/XX5GXV)

# %% [markdown]
# **Note:** This notebook is a code reference for video [**How to upload, read and download files in Google Colab**](https://youtu.be/SPLG8hyhCbc) on my YouTube channel.
#
# For more Python How-To videos [click here](https://www.youtube.com/channel/UC4WD4PpbbP9i_GJdFBCpSYQ/).

# %% [markdown]
# ## **Uploading files into notebook**

# %% [markdown]
# ### **Upload files from your local file system**

# %%
from google.colab import files

# %%
files.upload()

# %%
with open(file='Test.txt', mode='r') as f:
  print(f.read())

# %% [markdown]
# ### **Upload a file using url**

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip

# %%
# !unzip bank.zip

# %%
import pandas as pd
pd.read_csv('/content/bank.csv', sep=';').head()

# %% [markdown]
# ### **Mount your Google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## **Downloading files from notebook**

# %%
with open('example.txt', 'w') as f:
  f.write('some content')

# %%
from google.colab import files

# %%
files.download('example.txt')
